# %%
# import important library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
customers  = pd.read_csv('olist_customers_dataset.csv')
locations = pd.read_csv('olist_geolocation_dataset.csv')
order_items = pd.read_csv('olist_order_items_dataset.csv')
payments = pd.read_csv('olist_order_payments_dataset.csv')
reviews = pd.read_csv('olist_order_reviews_dataset.csv', sep= ';')
orders = pd.read_csv('olist_orders_dataset.csv')
products = pd.read_csv('olist_products_dataset.csv')
sellers = pd.read_csv('olist_sellers_dataset.csv')

# %%
pd.options.display.max_columns = 99

# %% [markdown]
# #### There are to many variable of the data, so we will selecting the useful variable to analyzed and visualized

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers[['customer_city', 'customer_state']].nunique()
# Out:
# customer_city     4119
# customer_state      27
# dtype: int64

# %%
# concat orders and customer city
sales = orders.merge(customers[['customer_id', 'customer_state']], on='customer_id')
sales.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date customer_state
# 0           2017-10-18 00:00:00             SP
# 1           2018-08-13 00:00:00             BA
# 2           2018-09-04 00:00:00             GO
# 3           2017-12-15 00:00:00             RN
# 4           2018-02-26 00:00:00             SP

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
sales = sales.merge(payments, on = 'order_id')
sales.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date customer_state  payment_sequential  \
# 0           2017-10-18 00:00:00             SP                   1
# 1           2017-10-18 00:00:00             SP                   3
# 2           2017-10-18 00:00:00             SP                   2
# 3           2018-08-13 00:00:00             BA                   1
# 4           2018-09-04 00:00:00             GO                   1
#
#   payment_type  payment_installments  payment_value
# 0  credit_card                     1          18.12
# 1      voucher                     1           2.00
# 2      voucher                     1          18.59
# 3       boleto                     1         141.46
# 4  credit_card                     3         179.12

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#   review_score review_comment_title  \
# 0            4                  NaN
# 1            5                  NaN
# 2            5                  NaN
# 3            5                  NaN
# 4            5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN     18/01/2018 00:00
# 1                                                NaN     10/03/2018 00:00
# 2                                                NaN     17/02/2018 00:00
# 3              Recebi bem antes do prazo estipulado.     21/04/2017 00:00
# 4  Parabéns lojas lannister adorei comprar pela I...     01/03/2018 00:00
#
#   review_answer_timestamp
# 0        18/01/2018 21:46
# 1        11/03/2018 03:05
# 2        18/02/2018 14:36
# 3        21/04/2017 22:02
# 4        02/03/2018 10:26

# %%
sales = sales.merge(reviews[['order_id', 'review_score']], on='order_id')
sales.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date customer_state  payment_sequential  \
# 0           2017-10-18 00:00:00             SP                   1
# 1           2017-10-18 00:00:00             SP                   3
# 2           2017-10-18 00:00:00             SP                   2
# 3           2018-08-13 00:00:00             BA                   1
# 4           2018-09-04 00:00:00             GO                   1
#
#   payment_type  payment_installments  payment_value review_score
# 0  credit_card                     1          18.12            4
# 1      voucher                     1           2.00            4
# 2      voucher                     1          18.59            4
# 3       boleto                     1         141.46            4
# 4  credit_card                     3         179.12            5

# %%
# total payment in sales same as total payment on order_items so we don't need to merge them
sales[sales['order_id'] == 'e481f51cbdc54678b7cc49136f2d6af7']['payment_value'].sum()
# Out:
# 38.71

# %%
order_items[order_items['order_id'] == 'e481f51cbdc54678b7cc49136f2d6af7']
# Out:
#                                 order_id  order_item_id  \
# 100785  e481f51cbdc54678b7cc49136f2d6af7              1
#
#                               product_id                         seller_id  \
# 100785  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
#
#         shipping_limit_date  price  freight_value
# 100785  2017-10-06 11:07:15  29.99           8.72

# %%
order_items['order_item_id'].nunique()
# Out:
# 21

# %%
sales = sales.merge(order_items[['order_id', 'order_item_id', 'product_id', 'seller_id']], on='order_id')
sales.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date customer_state  payment_sequential  \
# 0           2017-10-18 00:00:00             SP                   1
# 1           2017-10-18 00:00:00             SP                   3
# 2           2017-10-18 00:00:00             SP                   2
# 3           2018-08-13 00:00:00             BA                   1
# 4           2018-09-04 00:00:00             GO                   1
#
#   payment_type  payment_installments  payment_value review_score  \
# 0  credit_card                     1          18.12            4
# 1      voucher                     1           2.00            4
# 2      voucher                     1          18.59            4
# 3       boleto                     1         141.46            4
# 4  credit_card                     3         179.12            5
#
#    order_item_id                        product_id  \
# 0              1  87285b34884572647811a353c7ac498a
# 1              1  87285b34884572647811a353c7ac498a
# 2              1  87285b34884572647811a353c7ac498a
# 3              1  595fac2a385ac33a80bd5114aec74eb8
# 4              1  aa4383b373c6aca5d8797843e5594415
#
#                           seller_id
# 0  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  289cdb325fb7e7f891c38608bf9e0962
# 4  4869f7a5dfa277a7dca6462dcf3b52b2

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
sales = sales.merge(products[['product_id', 'product_category_name']], on='product_id')
sales.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4    delivered      2017-10-23 23:26:46  2017-10-25 02:14:11
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2017-08-17 15:28:33           2017-08-18 14:44:43
# 4          2017-10-27 16:48:46           2017-11-07 18:04:59
#
#   order_estimated_delivery_date customer_state  payment_sequential  \
# 0           2017-10-18 00:00:00             SP                   1
# 1           2017-10-18 00:00:00             SP                   3
# 2           2017-10-18 00:00:00             SP                   2
# 3           2017-08-28 00:00:00             SP                   1
# 4           2017-11-13 00:00:00             SC                   1
#
#   payment_type  payment_installments  payment_value review_score  \
# 0  credit_card                     1          18.12            4
# 1      voucher                     1           2.00            4
# 2      voucher                     1          18.59            4
# 3  credit_card                     3          37.77            4
# 4       boleto                     1          44.09            3
#
#    order_item_id                        product_id  \
# 0              1  87285b34884572647811a353c7ac498a
# 1              1  87285b34884572647811a353c7ac498a
# 2              1  87285b34884572647811a353c7ac498a
# 3              1  87285b34884572647811a353c7ac498a
# 4              1  87285b34884572647811a353c7ac498a
#
#                           seller_id  product_category_name
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 1  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 2  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 3  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 4  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas

# %%
sales['product_category_name'].nunique()
# Out:
# 73

# %%
product_name = pd.read_csv('product_category_name_translation.csv')
product_name.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
sales = sales.merge(product_name, on= 'product_category_name')

# %%
sales.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4    delivered      2017-10-23 23:26:46  2017-10-25 02:14:11
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2017-08-17 15:28:33           2017-08-18 14:44:43
# 4          2017-10-27 16:48:46           2017-11-07 18:04:59
#
#   order_estimated_delivery_date customer_state  payment_sequential  \
# 0           2017-10-18 00:00:00             SP                   1
# 1           2017-10-18 00:00:00             SP                   3
# 2           2017-10-18 00:00:00             SP                   2
# 3           2017-08-28 00:00:00             SP                   1
# 4           2017-11-13 00:00:00             SC                   1
#
#   payment_type  payment_installments  payment_value review_score  \
# 0  credit_card                     1          18.12            4
# 1      voucher                     1           2.00            4
# 2      voucher                     1          18.59            4
# 3  credit_card                     3          37.77            4
# 4       boleto                     1          44.09            3
#
#    order_item_id                        product_id  \
# 0              1  87285b34884572647811a353c7ac498a
# 1              1  87285b34884572647811a353c7ac498a
# 2              1  87285b34884572647811a353c7ac498a
# 3              1  87285b34884572647811a353c7ac498a
# 4              1  87285b34884572647811a353c7ac498a
#
#                           seller_id  product_category_name  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 1  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 2  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 3  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
# 4  3504c0cb71d7fa48d967e0e4c94d59d9  utilidades_domesticas
#
#   product_category_name_english
# 0                    housewares
# 1                    housewares
# 2                    housewares
# 3                    housewares
# 4                    housewares

# %%
sales.drop(['product_id', 
            'seller_id', 
            'product_category_name', 
            'customer_id', 
            'order_approved_at', 
            'order_delivered_carrier_date', 
            'order_delivered_customer_date', 'order_estimated_delivery_date'],
           axis=1, inplace= True)

# %%
sales.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 2  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 3  128e10d95713541c87cd1a2e48201934    delivered      2017-08-15 18:29:31
# 4  bfc39df4f36c3693ff3b63fcbea9e90a    delivered      2017-10-23 23:26:46
#
#   customer_state  payment_sequential payment_type  payment_installments  \
# 0             SP                   1  credit_card                     1
# 1             SP                   3      voucher                     1
# 2             SP                   2      voucher                     1
# 3             SP                   1  credit_card                     3
# 4             SC                   1       boleto                     1
#
#    payment_value review_score  order_item_id product_category_name_english
# 0          18.12            4              1                    housewares
# 1           2.00            4              1                    housewares
# 2          18.59            4              1                    housewares
# 3          37.77            4              1                    housewares
# 4          44.09            3              1                    housewares

# %%
sales.to_csv('sales.csv', index=False)

# %%
data= sales.copy()

# %%
data.isna().sum()
# Out:
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# customer_state                   0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_score                     0
# order_item_id                    0
# product_category_name_english    0
# dtype: int64

# %%
sns.countplot(data['order_status'])
# Out:
# C:\Users\62812\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='order_status', ylabel='count'>

# %%
data.shape
# Out:
# (109268, 11)

# %%
sns.barplot(x= data['customer_state'].value_counts().head(10), y= data['customer_state'].value_counts().head(10).index, palette= 'Blues')
# Out:
# <AxesSubplot:xlabel='customer_state'>

# %%
data.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 2  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 3  128e10d95713541c87cd1a2e48201934    delivered      2017-08-15 18:29:31
# 4  bfc39df4f36c3693ff3b63fcbea9e90a    delivered      2017-10-23 23:26:46
#
#   customer_state  payment_sequential payment_type  payment_installments  \
# 0             SP                   1  credit_card                     1
# 1             SP                   3      voucher                     1
# 2             SP                   2      voucher                     1
# 3             SP                   1  credit_card                     3
# 4             SC                   1       boleto                     1
#
#    payment_value review_score  order_item_id product_category_name_english
# 0          18.12            4              1                    housewares
# 1           2.00            4              1                    housewares
# 2          18.59            4              1                    housewares
# 3          37.77            4              1                    housewares
# 4          44.09            3              1                    housewares

# %%
plt.figure(figsize= (8,4))
sns.countplot(x= data['payment_type'], palette= 'Blues')
plt.title('Customer Payment Methods')
plt.show()

# %%
payment = data.groupby('order_id')['payment_sequential'].max().reset_index().sort_values(by='payment_sequential',ascending= False)
print(f"{round(len(payment[payment['payment_sequential'] > 1 ])/len(payment)*100)}% Customer using split payment")
print(f"{round(len(payment[payment['payment_sequential'] == 1 ])/len(payment)*100)}% Customer using cash payment")
# Out:
# 3% Customer using split payment
# 97% Customer using cash payment

# %%
data = data.rename(columns={'product_category_name_english': 'product_category'})

# %%
top_category = data['product_category'].value_counts().reset_index()
top_category.columns = ['product_category', 'sold']
plt.figure(figsize= (16,6))
sns.barplot(x= top_category.head(10)['product_category'], y=top_category.head(10)['sold'], palette= 'Blues')
plt.title('Top 10 Ordered Product Category')
plt.xticks(rotation=30)
plt.show()

# %%
top_category = data['product_category'].value_counts().sort_values().reset_index()
top_category.columns = ['product_category', 'sold']
plt.figure(figsize= (16,6))
sns.barplot(x= top_category.head(10)['product_category'], y=top_category.head(10)['sold'], palette= 'cubehelix')
plt.title('10 Lowest Ordered Product Category')
plt.xticks(rotation=30)
plt.show()

# %%
top_category_sales = data.groupby('product_category').sum()['payment_value'].reset_index().sort_values(by= 'payment_value', ascending= False)
top_category_sales.columns = ['product_category', 'sales']
plt.figure(figsize= (16,6))
sns.barplot(x= top_category_sales.head(10)['product_category'], y=top_category_sales.head(10)['sales'], palette= 'Blues')
plt.title('Top 10 Product Category Sales')
plt.xticks(rotation=30)
plt.show()

# %%
top_category_sales = data.groupby('product_category').sum()['payment_value'].reset_index().sort_values(by= 'payment_value')
top_category_sales.columns = ['product_category', 'sales']
plt.figure(figsize= (16,6))
sns.barplot(x= top_category_sales.head(10)['product_category'], y=top_category_sales.head(10)['sales'], palette= 'Blues')
plt.title('10 Lowest Product Category Sales')
plt.xticks(rotation=30)
plt.show()

# %%
top_country_sales = data.groupby('customer_state').sum()['payment_value'].reset_index().sort_values(by= 'payment_value', ascending= False)
top_country_sales.columns = ['country', 'sales']
plt.figure(figsize= (16,6))
sns.barplot(x= top_country_sales.head(10)['country'], y=top_country_sales.head(10)['sales'], palette= 'Blues')
plt.title('Top 10 Country Sales')
plt.show()

# %%
top_country_sales = data.groupby('customer_state').sum()['payment_value'].reset_index().sort_values(by= 'payment_value')
top_country_sales.columns = ['country', 'sales']
plt.figure(figsize= (16,6))
sns.barplot(x= top_country_sales.head(10)['country'], y=top_country_sales.head(10)['sales'], palette= 'flare')
plt.title('10 Lowest Country Sales')
plt.show()

# %%
data.select_dtypes('object')
# Out:
#                                 order_id order_status  \
# 0       e481f51cbdc54678b7cc49136f2d6af7    delivered
# 1       e481f51cbdc54678b7cc49136f2d6af7    delivered
# 2       e481f51cbdc54678b7cc49136f2d6af7    delivered
# 3       128e10d95713541c87cd1a2e48201934    delivered
# 4       bfc39df4f36c3693ff3b63fcbea9e90a    delivered
# ...                                  ...          ...
# 109263  0b82d0616f1ad8da15cf967b984b4004    delivered
# 109264  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 109265  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 109266  2c4ada2e75c2ad41dd93cebb5df5f023    delivered
# 109267  bede3503afed051733eeb4a84d1adcc5    delivered
#
#        order_purchase_timestamp customer_state payment_type review_score  \
# 0           2017-10-02 10:56:33             SP  credit_card            4
# 1           2017-10-02 10:56:33             SP      voucher            4
# 2           2017-10-02 10:56:33             SP      voucher            4
# 3           2017-08-15 18:29:31             SP  credit_card            4
# 4           2017-10-23 23:26:46             SC       boleto            3
# ...                         ...            ...          ...          ...
# 109263      2018-08-03 21:35:53             MG       boleto            5
# 109264      2018-07-23 18:35:14             SP  credit_card            3
# 109265      2018-07-23 18:35:14             SP  credit_card            3
# 109266      2017-01-26 11:09:00             RO  credit_card            4
# 109267      2017-09-17 16:51:43             DF       boleto            1
#
#              product_category
# 0                  housewares
# 1                  housewares
# 2                  housewares
# 3                  housewares
# 4                  housewares
# ...                       ...
# 109263  arts_and_craftmanship
# 109264  arts_and_craftmanship
# 109265  arts_and_craftmanship
# 109266  security_and_services
# 109267  security_and_services
#
# [109268 rows x 7 columns]

# %%
data['order_status'] = data['order_status'].map({'delivered':1, 'shipped':0})

# %%
data.head()
# Out:
#                            order_id  order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7           1.0      2017-10-02 10:56:33
# 1  e481f51cbdc54678b7cc49136f2d6af7           1.0      2017-10-02 10:56:33
# 2  e481f51cbdc54678b7cc49136f2d6af7           1.0      2017-10-02 10:56:33
# 3  128e10d95713541c87cd1a2e48201934           1.0      2017-08-15 18:29:31
# 4  bfc39df4f36c3693ff3b63fcbea9e90a           1.0      2017-10-23 23:26:46
#
#   customer_state  payment_sequential payment_type  payment_installments  \
# 0             SP                   1  credit_card                     1
# 1             SP                   3      voucher                     1
# 2             SP                   2      voucher                     1
# 3             SP                   1  credit_card                     3
# 4             SC                   1       boleto                     1
#
#    payment_value review_score  order_item_id product_category
# 0          18.12            4              1       housewares
# 1           2.00            4              1       housewares
# 2          18.59            4              1       housewares
# 3          37.77            4              1       housewares
# 4          44.09            3              1       housewares

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109268 entries, 0 to 109267
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  109268 non-null  object
#  1   order_status              108110 non-null  float64
#  2   order_purchase_timestamp  109268 non-null  object
#  3   customer_state            109268 non-null  object
#  4   payment_sequential        109268 non-null  int64
#  5   payment_type              109268 non-null  object
#  6   payment_installments      109268 non-null  int64
#  7   payment_value             109268 non-null  float64
#  8   review_score              109268 non-null  object
#  9   order_item_id             109268 non-null  int64
#  10  product_category          109268 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 14.0+ MB

# %%
data['order_purchase_timestamp'] = pd.to_datetime(data['order_purchase_timestamp'])

# %%
data.head()
# Out:
#                            order_id  order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7           1.0      2017-10-02 10:56:33
# 1  e481f51cbdc54678b7cc49136f2d6af7           1.0      2017-10-02 10:56:33
# 2  e481f51cbdc54678b7cc49136f2d6af7           1.0      2017-10-02 10:56:33
# 3  128e10d95713541c87cd1a2e48201934           1.0      2017-08-15 18:29:31
# 4  bfc39df4f36c3693ff3b63fcbea9e90a           1.0      2017-10-23 23:26:46
#
#   customer_state  payment_sequential payment_type  payment_installments  \
# 0             SP                   1  credit_card                     1
# 1             SP                   3      voucher                     1
# 2             SP                   2      voucher                     1
# 3             SP                   1  credit_card                     3
# 4             SC                   1       boleto                     1
#
#    payment_value review_score  order_item_id product_category
# 0          18.12            4              1       housewares
# 1           2.00            4              1       housewares
# 2          18.59            4              1       housewares
# 3          37.77            4              1       housewares
# 4          44.09            3              1       housewares

# %%
plt.figure(figsize=(18,4))
monthly_sales = data[data['order_purchase_timestamp'].dt.year== 2017].groupby(data['order_purchase_timestamp'].dt.month).sum()['payment_value'].reset_index()
sns.lineplot(x= monthly_sales['order_purchase_timestamp'], y= monthly_sales['payment_value'],  size=12)
plt.xticks(ticks=monthly_sales['order_purchase_timestamp'])
plt.title('Monthly Sales 2017')
plt.xlabel('Month', size=12)
plt.ylabel('Sales', size=12)
plt.show()

# %% [markdown]
# ##### in 2017, Olist highest revenue happened in march

# %%
plt.figure(figsize=(18,4))
monthly_sales = data[(data['order_purchase_timestamp'].dt.year== 2017) & (data['order_purchase_timestamp'].dt.month == 11)].groupby(data['order_purchase_timestamp'].dt.day).sum()['payment_value'].reset_index()
sns.lineplot(x= monthly_sales['order_purchase_timestamp'], y= monthly_sales['payment_value'],  size=12)
plt.xticks(ticks=monthly_sales['order_purchase_timestamp'])
plt.title('Daily Sales 2017')
plt.xlabel('Day', size=12)
plt.ylabel('Sales', size=12)
plt.show()

# %% [markdown]
# ##### in March 2017, Olist highest revenue happened at day 24

# %%
plt.figure(figsize=(18,4))
monthly_sales = data.groupby([data['order_purchase_timestamp'].dt.hour]).count()['payment_value'].reset_index()
sns.lineplot(x= monthly_sales['order_purchase_timestamp'], y= monthly_sales['payment_value'],  size=12)
plt.xticks(ticks=monthly_sales['order_purchase_timestamp'])
plt.title('Hourly Transaction')
plt.xlabel('Hour', size=12)
plt.ylabel('Transaction', size=12)
plt.show()

# %% [markdown]
# ##### Most of the transaction happened on 9 AM - 10 PM

# %%
data['review_score'] = data['review_score'].astype('float')

# %%
sns.regplot(y = data['payment_value'], x = data['review_score'])
# Out:
# <AxesSubplot:xlabel='review_score', ylabel='payment_value'>

# %%
plt.figure(figsize=(8,6))
data.corr()['payment_value'].sort_values().drop('payment_value').plot(kind='bar')
plt.title('Payment Value Correlation')
plt.show()

# %%
plt.figure(figsize=(8,6))
data.corr()['review_score'].sort_values().drop('review_score').plot(kind='bar')
plt.title('Review Score Correlation')
plt.show()

# %%
data = data[(data['payment_value'] > 0) & (data['payment_value'] < 1000)]

# %%
data.describe()
# Out:
#         order_status  payment_sequential  payment_installments  payment_value  \
# count  106614.000000       107721.000000          107721.00000  107721.000000
# mean        0.990095            1.095432               2.89276     149.807908
# std         0.099030            0.744936               2.72356     144.389682
# min         0.000000            1.000000               0.00000       0.010000
# 25%         1.000000            1.000000               1.00000      59.960000
# 50%         1.000000            1.000000               1.00000     106.200000
# 75%         1.000000            1.000000               4.00000     183.470000
# max         1.000000           29.000000              24.00000     999.680000
#
#         review_score  order_item_id
# count  107721.000000  107721.000000
# mean        4.071927       1.177440
# std         1.355815       0.615121
# min         1.000000       1.000000
# 25%         4.000000       1.000000
# 50%         5.000000       1.000000
# 75%         5.000000       1.000000
# max         5.000000      21.000000

# %%
data.to_csv('sales.csv', index= True)
